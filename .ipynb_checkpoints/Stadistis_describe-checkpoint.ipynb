# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
numbers = [45,67,90,69,12, 34, 78]
print(f"Numeros: {numbers}")
print('Estadisticas Descriptivas:')
print(pd.DataFrame(numbers, columns = ['Values']).describe())
# Out:
# Numeros: [45, 67, 90, 69, 12, 34, 78]
# Estadisticas Descriptivas:
#           Values
# count   7.000000
# mean   56.428571
# std    27.293816
# min    12.000000
# 25%    39.500000
# 50%    67.000000
# 75%    73.500000
# max    90.000000

# %%
mean = np.mean(numbers)

# %%
median = np.median(numbers)

# %%
mode = stats.mode(numbers)
#Rango
rango = max(numbers) - min(numbers)
iqr = stats.iqr(numbers)
print(f'Media: {mean}\n Mediana: {median} \n')
if mode.count > 1:
    print(f'El valor mas repetido es: {mode}')
else:
    print('No existen valores repetidos en esta lista')
print(f"Rango: {rango}")
print(f'Deteccion de valores atipicos: {iqr}')
# Out:
# Media: 56.42857142857143
#  Mediana: 67.0
#
# No existen valores repetidos en esta lista
# Rango: 78
# Deteccion de valores atipicos: 34.0
