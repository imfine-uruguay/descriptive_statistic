# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
numbers = [45,67,90,69,12, 34, 78, 45]
print(f"Numeros: {numbers}")
print('Estadisticas Descriptivas:')
print(pd.DataFrame(numbers, columns = ['Values']).describe())
# Out:
# Numeros: [45, 67, 90, 69, 12, 34, 78, 45]
# Estadisticas Descriptivas:
#           Values
# count   8.000000
# mean   55.000000
# std    25.590177
# min    12.000000
# 25%    42.250000
# 50%    56.000000
# 75%    71.250000
# max    90.000000

# %%
mean = np.mean(numbers)

# %%
median = np.median(numbers)

# %%
mode = stats.mode(numbers)
#Rango
rango = max(numbers) - min(numbers)
iqr = stats.iqr(numbers)
print(f'Media: {mean}\n Mediana: {median} \n')
if mode.count > 1:
    print(f'El valor mas repetido es: {mode.mode}')
else:
    print('No existen valores repetidos en esta lista')
print(f"Rango: {rango}")
print(f'Deteccion de valores atipicos: {iqr}')
# Out:
# Media: 55.0
#  Mediana: 56.0
#
# El valor mas repetido es: 45
# Rango: 78
# Deteccion de valores atipicos: 29.0

# %%
variance = np.var(numbers, ddof=1)
desviation_std = np.std(numbers, ddof=1)
print(f'La varianza es: {variance}')
print(f'La desviacion estandas: {desviation_std}')
# Out:
# La varianza es: 654.8571428571429
# La desviacion estandas: 25.590176686712088

# %%
cv = (desviation_std/mean) * 100
print(f"Coeficiente de desviacion: {cv}")
# Out:
# Coeficiente de desviacion: 46.52759397584016

# %%
print(sorted(numbers))
# Out:
# [12, 34, 45, 45, 67, 69, 78, 90]

# %%
print(median)
# Out:
# 56.0

# %%
plt.figure(figsize=(18,5))
sns.histplot(numbers, bins=5, kde=True)
plt.title('Histograma de Datos')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.boxplot(numbers)
plt.title('Boxplot para analisis de dispersion')
plt.show()

# %%
df = pd.DataFrame({"Values": numbers})
df.plot(kind='bar')
plt.title('Grafico de barras')
plt.show()

# %%
data = {"Name": ['Yoeny', 'Dunieska', 'Samuel', 'Sofia'], 'Edad': [42, 45, 9, 11], 'Altura': [1.67, 1.60, 1, 1.20]}
df = pd.DataFrame(data)
age = df['Edad']
plt.bar(df['Name'], age, color ='skyblue')
plt.title('Edades de personas')
plt.xlabel('Nombre')
plt.ylabel('Edad')
plt.show()

# %%
with open('elements.txt', 'w') as a:
    a.write('eres un archivo creado desde aca\n')
    a.write('fin del archivo')

# %%
with open('elements.txt', 'r') as a:
    lines = a.readlines()
    print(lines)
# Out:
# ['eres un archivo creado desde aca\n', 'fin del archivo']

# %%
archive_path = 'adult.csv'
adult = pd.read_csv(archive_path)
adult.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 archive_path = 'adult.csv'
# ----> 2 adult = pd.read_csv(archive_path)
#       3 adult.head()
#
# File ~/Projects/python/Repaso/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:872, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     860 kwds_defaults = _refine_defaults_read(
#     861     dialect,
#     862     delimiter,
#    (...)    868     dtype_backend=dtype_backend,
#     869 )
#     870 kwds.update(kwds_defaults)
# --> 872 return _read(filepath_or_buffer, kwds)
#
# File ~/Projects/python/Repaso/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/Projects/python/Repaso/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1643, in TextFileReader.__init__(self, f, engine, **kwds)
#    1640     self.options["has_index_names"] = kwds["has_index_names"]
#    1642 self.handles: IOHandles | None = None
# -> 1643 self._engine = self._make_engine(f, self.engine)
#
# File ~/Projects/python/Repaso/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1907, in TextFileReader._make_engine(self, f, engine)
#    1905     if "b" not in mode:
#    1906         mode += "b"
# -> 1907 self.handles = get_handle(
#    1908     f,
#    1909     mode,
#    1910     encoding=self.options.get("encoding", None),
#    1911     compression=self.options.get("compression", None),
#    1912     memory_map=self.options.get("memory_map", False),
#    1913     is_text=is_text,
#    1914     errors=self.options.get("encoding_errors", "strict"),
#    1915     storage_options=self.options.get("storage_options", None),
#    1916 )
#    1917 assert self.handles is not None
#    1918 f = self.handles.handle
#
# File ~/Projects/python/Repaso/.venv/lib/python3.14/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'adult.csv'

# %%
adult.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 adult.describe()
#
# NameError: name 'adult' is not defined

# %%
adult.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 adult.tail()
#
# NameError: name 'adult' is not defined

# %%
adult.describe(include=['object', 'str'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 adult.describe(include=['object', 'str'])
#
# NameError: name 'adult' is not defined

# %%
adult.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 adult.info()
#
# NameError: name 'adult' is not defined

# %%
adult['age'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 adult['age'].describe()
#
# NameError: name 'adult' is not defined

# %%
rename_age = adult.rename(columns={'age': 'edad'})
rename_age.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 rename_age = adult.rename(columns={'age': 'edad'})
#       2 rename_age.head()
#
# NameError: name 'adult' is not defined

# %%
delete_columns_education_num = adult.drop(columns=['education.num'])
delete_columns_education_num.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 delete_columns_education_num = adult.drop(columns=['education.num'])
#       2 delete_columns_education_num.head()
#
# NameError: name 'adult' is not defined

# %%
group_age = adult.groupby('hours.per.week')['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 group_age = adult.groupby('hours.per.week')['age'].mean()
#
# NameError: name 'adult' is not defined

# %%
group_age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 group_age
#
# NameError: name 'group_age' is not defined

# %%
group_age.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 group_age.head()
#
# NameError: name 'group_age' is not defined

# %%
db_path = './db_source/'
adult.to_csv(db_path + 'copy_adult.csv', index=False)

# %%
df_new = pd.read_csv(db_path + 'copy_adult.csv')

# %%
df_new.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
import pyodbc
import pandas as pd
import os
from dotenv import load_dotenv

# %%
load_dotenv()

host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')
db = os.getenv('DB_NAME')
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')

conexion_str = (
    f'Driver={{ODBC Driver 18 for SQL Server}};'
    f'Server={host},{port};'
    f'Database={db};'
    f'UID={user};'
    f'PWD={password};'
    f'TrustServerCertificate=yes;'
)
conn = pyodbc.connect(conexion_str)
cursor = conn.cursor()

# %%
table_name = 'adulto'
load_df = pd.read_csv('./db_source/copy_adult.csv')

# %%
create_table_query = f"""
IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = '{table_name}')
BEGIN
    CREATE TABLE {table_name} (
        age int,
        workclass varchar(50),
        fnlwgt int,
        education varchar(50),
        education_num int,
        marital_status varchar(50),
        occupation varchar(50),
        relation_ship varchar(50),
        race varchar(50),
        sex varchar(50),
        capital_gain int,
        capital_lost int,
        hours_per_week int,
        native_country varchar(50),
        income varchar(20)
    )
END
"""

cursor.execute(create_table_query)
conn.commit()

# %%
insert_query = f'''INSERT INTO {table_name}
                (age, workclass, fnlwgt, education, education_num, marital_status, occupation, relation_ship, race,
                sex, capital_gain, capital_lost, hours_per_week, native_country, income)
                VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'''

data = [tuple(row) for _, row in adult.iterrows()]
cursor.executemany(insert_query, data)
conn.commit()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[69], line 7
#       3                 sex, capital_gain, capital_lost, hours_per_week, native_country, income)
#       4                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'''
#       5
#       6 data = [tuple(row) for _, row in adult.iterrows()]
# ----> 7 cursor.executemany(insert_query, data)
#       8 conn.commit()
#       9 cursor.close()
#      10 conn.close()
#
# ProgrammingError: Attempt to use a closed cursor.

# %%
new_conn = pyodbc.connect(conexion_str)
select_query = f'''select * from {table_name} where age > ?'''
df = pd.read_sql(select_query, new_conn, params=[30])
new_conn.close()
print(df.shape)
df.head()
# Out:
# /tmp/ipykernel_16671/1452421306.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(select_query, new_conn, params=[30])
# (21989, 15)
#    age workclass  fnlwgt     education  education_num marital_status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation  relation_ship   race     sex  capital_gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital_lost  hours_per_week native_country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %%
plt.figure(figsize=(10,6))
sex_count = df['sex'].value_counts()

# %%
plt.bar(sex_count.index, sex_count.values, color=['blue', 'orange'])
plt.title('Grafico de barras')
plt.xlabel('Sexo')
plt.ylabel('Freciencia')
# Out:
# Text(0, 0.5, 'Freciencia')

# %%
sns.scatterplot(x='age', y='hours_per_week', data=df, hue='sex')
plt.title("Edad vs horas por semanas")
plt.show()

# %%
men_age = np.mean(df['age'])

# %%
men_age
# Out:
# np.float64(45.573604984310336)

# %%
df['age']
# Out:
# 0        90
# 1        82
# 2        66
# 3        54
# 4        41
#          ..
# 21984    43
# 21985    32
# 21986    53
# 21987    40
# 21988    58
# Name: age, Length: 21989, dtype: int64

# %%
med = df['age'].median()
med
# Out:
# np.float64(44.0)

# %%
count_age_sup_50 = np.sum(df['age']> 50)
count_age_sup_50
# Out:
# np.int64(6460)

# %%
import pandas as pd
columns_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

# %%
file_path = './db_source/db/iris.data'
df = pd.read_csv(file_path, header=None, names=columns_names)

# %%
df.head(50)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa
# 30           4.8          3.1           1.6          0.2  Iris-setosa
# 31           5.4          3.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 34           4.9          3.1           1.5          0.1  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 37           4.9          3.1           1.5          0.1  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 39           5.1          3.4           1.5          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 43           5.0          3.5           1.6          0.6  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 45           4.8          3.0           1.4          0.3  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa
# 47           4.6          3.2           1.4          0.2  Iris-setosa
# 48           5.3          3.7           1.5          0.2  Iris-setosa
# 49           5.0          3.3           1.4          0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
df.to_csv('./db_source/db/iris_cleaned.data', index=False)
