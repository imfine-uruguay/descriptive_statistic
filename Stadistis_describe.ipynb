# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
import seaborn as sns

# %%
numbers = [45,67,90,69,12, 34, 78, 45]
print(f"Numeros: {numbers}")
print('Estadisticas Descriptivas:')
print(pd.DataFrame(numbers, columns = ['Values']).describe())
# Out:
# Numeros: [45, 67, 90, 69, 12, 34, 78, 45]
# Estadisticas Descriptivas:
#           Values
# count   8.000000
# mean   55.000000
# std    25.590177
# min    12.000000
# 25%    42.250000
# 50%    56.000000
# 75%    71.250000
# max    90.000000

# %%
mean = np.mean(numbers)

# %%
median = np.median(numbers)

# %%
mode = stats.mode(numbers)
#Rango
rango = max(numbers) - min(numbers)
iqr = stats.iqr(numbers)
print(f'Media: {mean}\n Mediana: {median} \n')
if mode.count > 1:
    print(f'El valor mas repetido es: {mode.mode}')
else:
    print('No existen valores repetidos en esta lista')
print(f"Rango: {rango}")
print(f'Deteccion de valores atipicos: {iqr}')
# Out:
# Media: 56.42857142857143
#  Mediana: 67.0
#
# El valor mas repetido es: 45
# Rango: 78
# Deteccion de valores atipicos: 29.0

# %%
variance = np.var(numbers, ddof=1)
desviation_std = np.std(numbers, ddof=1)
print(f'La varianza es: {variance}')
print(f'La desviacion estandas: {desviation_std}')
# Out:
# La varianza es: 654.8571428571429
# La desviacion estandas: 25.590176686712088

# %%
cv = (desviation_std/mean) * 100
print(f"Coeficiente de desviacion: {cv}")
# Out:
# Coeficiente de desviacion: 45.3496802042999

# %%
print(sorted(numbers))
# Out:
# [12, 34, 45, 45, 67, 69, 78, 90]

# %%
print(median)
# Out:
# 67.0

# %%
plt.figure(figsize=(18,5))
sns.histplot(numbers, bins=5, kde=True)
plt.title('Histograma de Datos')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.boxplot(numbers)
plt.title('Boxplot para analisis de dispersion')
plt.show()

# %%
df = pd.DataFrame({"Values": numbers})
df.plot(kind='bar')
plt.title('Grafico de barras')
plt.show()

# %%
data = {"Name": ['Yoeny', 'Dunieska', 'Samuel', 'Sofia'], 'Edad': [42, 45, 9, 11], 'Altura': [1.67, 1.60, 1, 1.20]}
df = pd.DataFrame(data)
age = df['Edad']
plt.bar(df['Name'], age, color ='skyblue')
plt.title('Edades de personas')
plt.xlabel('Nombre')
plt.ylabel('Edad')
plt.show()

# %%
with open('elements.txt', 'w') as a:
    a.write('eres un archivo creado desde aca\n')
    a.write('fin del archivo')

# %%
with open('elements.txt', 'r') as a:
    lines = a.readlines()
    print(lines)
# Out:
# ['eres un archivo creado desde aca\n', 'fin del archivo']

# %%
archive_path = 'adult.csv'
adult = pd.read_csv(archive_path)
adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
adult.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
adult.tail()
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# ...

# %%
adult.describe(include=['object', 'str'])
# Out:
#        workclass education      marital.status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native.country income
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
adult.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  str
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  str
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  str
#  6   occupation      32561 non-null  str
#  7   relationship    32561 non-null  str
#  8   race            32561 non-null  str
#  9   sex             32561 non-null  str
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  str
#  14  income          32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %%
adult['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
rename_age = adult.rename(columns={'age': 'edad'})
rename_age.head()
# Out:
#    edad workclass  fnlwgt     education  education.num marital.status  \
# 0    90         ?   77053       HS-grad              9        Widowed
# 1    82   Private  132870       HS-grad              9        Widowed
# 2    66         ?  186061  Some-college             10        Widowed
# 3    54   Private  140359       7th-8th              4       Divorced
# 4    41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
delete_columns_education_num = adult.drop(columns=['education.num'])
delete_columns_education_num.head()
# Out:
#    age workclass  fnlwgt     education marital.status         occupation  \
# 0   90         ?   77053       HS-grad        Widowed                  ?
# 1   82   Private  132870       HS-grad        Widowed    Exec-managerial
# 2   66         ?  186061  Some-college        Widowed                  ?
# 3   54   Private  140359       7th-8th       Divorced  Machine-op-inspct
# 4   41   Private  264663  Some-college      Separated     Prof-specialty
#
#     relationship   race     sex  capital.gain  capital.loss  hours.per.week  \
# 0  Not-in-family  White  Female             0          4356              40
# 1  Not-in-family  White  Female             0          4356              18
# 2      Unmarried  Black  Female             0          4356              40
# 3      Unmarried  White  Female             0          3900              40
# 4      Own-child  White  Female             0          3900              40
#
#   native.country income
# 0  United-States  <=50K
# ...

# %%
group_age = adult.groupby('hours.per.week')['age'].mean()

# %%
group_age
# Out:
# hours.per.week
# 1     61.550000
# 2     54.906250
# 3     53.564103
# 4     46.462963
# 5     46.683333
#         ...
# 95    38.500000
# 96    36.600000
# 97    30.000000
# 98    42.818182
# 99    43.517647
# Name: age, Length: 94, dtype: float64

# %%
group_age.head()
# Out:
# hours.per.week
# 1    61.550000
# 2    54.906250
# 3    53.564103
# 4    46.462963
# 5    46.683333
# Name: age, dtype: float64

# %%
db_path = './db_source/'
adult.to_csv(db_path + 'copy_adult.csv', index=False)

# %%
df_new = pd.read_csv(db_path + 'copy_adult.csv')

# %%
df_new.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
import pyodbc
import pandas as pd
import os
from dotenv import load_dotenv

# %%
load_dotenv()

host = os.getenv('DB_HOST')
port = os.getenv('DB_PORT')
db = os.getenv('DB_NAME')
user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')

conexion_str = (
    f'Driver={{ODBC Driver 18 for SQL Server}};'
    f'Server={host},{port};'
    f'Database={db};'
    f'UID={user};'
    f'PWD={password};'
    f'TrustServerCertificate=yes;'
)
conn = pyodbc.connect(conexion_str)
cursor = conn.cursor()

# %%
table_name = 'adulto'
load_df = pd.read_csv('./db_source/copy_adult.csv')

# %%
create_table_query = f"""
IF NOT EXISTS (SELECT * FROM sys.tables WHERE name = '{table_name}')
BEGIN
    CREATE TABLE {table_name} (
        age int,
        workclass varchar(50),
        fnlwgt int,
        education varchar(50),
        education_num int,
        marital_status varchar(50),
        occupation varchar(50),
        relation_ship varchar(50),
        race varchar(50),
        sex varchar(50),
        capital_gain int,
        capital_lost int,
        hours_per_week int,
        native_country varchar(50),
        income varchar(20)
    )
END
"""

cursor.execute(create_table_query)
conn.commit()

# %%
insert_query = f'''INSERT INTO {table_name}
                (age, workclass, fnlwgt, education, education_num, marital_status, occupation, relation_ship, race,
                sex, capital_gain, capital_lost, hours_per_week, native_country, income)
                VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'''

data = [tuple(row) for _, row in adult.iterrows()]
cursor.executemany(insert_query, data)
conn.commit()
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[69], line 7
#       3                 sex, capital_gain, capital_lost, hours_per_week, native_country, income)
#       4                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)'''
#       5
#       6 data = [tuple(row) for _, row in adult.iterrows()]
# ----> 7 cursor.executemany(insert_query, data)
#       8 conn.commit()
#       9 cursor.close()
#      10 conn.close()
#
# ProgrammingError: Attempt to use a closed cursor.

# %%
new_conn = pyodbc.connect(conexion_str)
select_query = f'''select * from {table_name} where age > ?'''
df = pd.read_sql(select_query, new_conn, params=[30])
new_conn.close()
print(df.shape)
df.head()
# Out:
# (21989, 15)
# /tmp/ipykernel_19764/1452421306.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(select_query, new_conn, params=[30])
#    age workclass  fnlwgt     education  education_num marital_status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation  relation_ship   race     sex  capital_gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# ...

# %%
plt.figure(figsize=(10,6))
sex_count = df['sex'].value_counts()

# %%
plt.bar(sex_count.index, sex_count.values, color=['blue', 'orange'])
plt.title('Grafico de barras')
plt.xlabel('Sexo')
prl.ylabel('Freciencia')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 4
#       1 plt.bar(sex_count.index, sex_count.values, color=['blue', 'orange'])
#       2 plt.title('Grafico de barras')
#       3 plt.xlabel('Sexo')
# ----> 4 prl.ylabel('Freciencia')
#
# NameError: name 'prl' is not defined
